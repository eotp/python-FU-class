# %% [markdown]
# # Data Preperation for Streamlit WW2 Implementation
# Our WW2 data contains attacks on individual coordinates.
#
# In this session we want to create a nice looking web-page that let's us easily compare statistics between individual countries.
#
# In order to do this we have to aggregate our individual coordinate-based data to per-country data.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Load Raw Data

# %%
# load data on european countries
europe = pd.read_pickle("../data/europe.p").to_crs("EPSG:4326")
# contains all countries intersecting our polygon from the WW2 analysis
europe.sample(5)# not only european countries per se
# columns of interest for us: name and geometry
europe.head()
# Out:
#      pop_est      continent       name iso_a3  gdp_md_est  \
# 0  142257519         Europe     Russia    RUS   3745000.0
# 1    5320045         Europe     Norway    -99    364700.0
# 2      57713  North America  Greenland    GRL      2173.0
# 3   67106161         Europe     France    -99   2699000.0
# 4    8299706           Asia     Israel    ISR    297000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((45.00000 42.60827, 44.53762 42...
# 1  POLYGON ((31.10104 69.55810, 29.39955 69.15692...
# 2  POLYGON ((-20.72922 73.50000, -20.76234 73.464...
# 3  MULTIPOLYGON (((8.74601 42.62812, 9.39000 43.0...
# 4  POLYGON ((35.05295 33.00000, 35.09846 33.08054...

# %%
# load WW2 data for target_df
# geometry contains coordinate POINTS
europe_data = pd.read_pickle("../data/gdf_europe.p").to_crs("EPSG:4326")
europe_data.head()
# Out:
#    country code  country name of powerplant  capacity in MW  latitude  \
# 9           ALB  Albania         Bistrica 1            27.0   39.9116
# 10          ALB  Albania             Fierza           500.0   42.2514
# 11          ALB  Albania              Koman           600.0   42.1033
# 12          ALB  Albania         Lanabregas             5.0   41.3428
# 13          ALB  Albania            Shkopet            24.0   41.6796
#
#     longitude primary_fuel  start date owner of plant geolocation_source  \
# 9     20.1047        Hydro        1965            NaN              GEODB
# 10    20.0431        Hydro        1978            NaN              GEODB
# 11    19.8224        Hydro        1985            NaN              GEODB
# 12    19.8964        Hydro        1951            NaN              GEODB
# 13    19.8305        Hydro        1963            NaN              GEODB
#
#     estimated_generation_gwh_2020  green continent                   geometry
# 9                           88.45   True    Europe  POINT (20.10470 39.91160)
# 10                        1648.24   True    Europe  POINT (20.04310 42.25140)
# 11                        1982.72   True    Europe  POINT (19.82240 42.10330)
# 12                          15.23   True    Europe  POINT (19.89640 41.34280)
# 13                          83.57   True    Europe  POINT (19.83050 41.67960)

# %% [markdown]
# ## Replace target coordinates by target countries polygons

# %%
res_intersect_europe = gpd.overlay(europe_data, europe, how='intersection')
# Basically checks for each geometry in "europe_data" (target coordinates) 
# if intersects with geometry of "target_df" (country)
# -> Merges both dataframes and keeps country polygon instead of target coordinates
res_intersect_europe.head()
# Out:
#   country code  country name of powerplant  capacity in MW  latitude  \
# 0          ALB  Albania         Bistrica 1            27.0   39.9116
# 1          ALB  Albania             Fierza           500.0   42.2514
# 2          ALB  Albania              Koman           600.0   42.1033
# 3          ALB  Albania         Lanabregas             5.0   41.3428
# 4          ALB  Albania            Shkopet            24.0   41.6796
#
#    longitude primary_fuel  start date owner of plant geolocation_source  \
# 0    20.1047        Hydro        1965            NaN              GEODB
# 1    20.0431        Hydro        1978            NaN              GEODB
# 2    19.8224        Hydro        1985            NaN              GEODB
# 3    19.8964        Hydro        1951            NaN              GEODB
# 4    19.8305        Hydro        1963            NaN              GEODB
#
#    estimated_generation_gwh_2020  green continent_1  pop_est continent_2  \
# 0                          88.45   True      Europe  3047987      Europe
# 1                        1648.24   True      Europe  3047987      Europe
# 2                        1982.72   True      Europe  3047987      Europe
# 3                          15.23   True      Europe  3047987      Europe
# 4                          83.57   True      Europe  3047987      Europe
#
#       name iso_a3  gdp_md_est                   geometry
# 0  Albania    ALB     33900.0  POINT (20.10470 39.91160)
# 1  Albania    ALB     33900.0  POINT (20.04310 42.25140)
# 2  Albania    ALB     33900.0  POINT (19.82240 42.10330)
# 3  Albania    ALB     33900.0  POINT (19.89640 41.34280)
# 4  Albania    ALB     33900.0  POINT (19.83050 41.67960)

# %%
# Set index to country name so we can directly insert data grouped by country name
europe.set_index("name", inplace=True, drop=False)

# %%
def insert_totals(target_df, data_df):
    # get attack counts and total weight of explosives per year
    # and apply it to a given target country
    # get totals
    target_df[f"N_powerplants"] = data_df.groupby("name").size()
    target_df[f"N_green"] = data_df.loc[data_df["green"]].groupby("name").size()
    # replace NaN (no a number) values with 0
    target_df.fillna(0, inplace=True)
    n_green = data_df.groupby(["name", "green"])["name"].size().unstack()
    target_df["green_ratio"] = (n_green[True] / n_green.sum(axis=1)).fillna(0)
    return target_df

# %%
europe = insert_totals(europe, res_intersect_europe)

# %%
europe = europe.loc[europe["continent"] == "Europe"]

# %%
def insert_fuel_types(target_df, data_df):
    for pp_type in data_df["primary_fuel"].unique():
        target_df[f"N_fuel_{pp_type}"] = data_df.loc[data_df["primary_fuel"] == pp_type].groupby("name").size()
        data_df.loc[data_df["primary_fuel"] == pp_type, f"is_{pp_type}"] = True
        data_df.loc[data_df["primary_fuel"] != pp_type, f"is_{pp_type}"] = False 
        ratio = data_df.groupby(["name", f"is_{pp_type}"]).size().unstack().fillna(0)
        target_df[f"fuel_ratio_{pp_type}"] = ratio[True] / ratio.sum(axis=1)

        production = data_df.groupby(["name", f"is_{pp_type}"])["estimated_generation_gwh_2020"].sum().unstack().fillna(0)

        target_df[f"fuel_generation_ratio_{pp_type}"] = production[True] / production.sum(axis=1)
        target_df[f"fuel_generation_total_{pp_type}"] = production[True]
    return target_df

# %%
europe = insert_fuel_types(europe, res_intersect_europe).fillna(0)

# %% [markdown]
# # German Bundeslaender

# %%
# load data containing German Bundesländer
# similarly to the europe dataset it contains polygons mapping individual Bundesländer
bl = gpd.read_file('../data/vg2500_geo84.zip').to_crs("EPSG:4326")
# rename the column that specifies the name so that is the same with the remaining data
bl.rename({"GEN": "name"}, axis=1, inplace=True)

# %%
bl.head()
# Out:
#    USE  RS        RS_ALT                 name    SHAPE_LENG    SHAPE_AREA  \
# 0    2  02  020000000000              Hamburg  1.752538e+05  7.605398e+08
# 1    2  03  030000000000        Niedersachsen  2.016496e+06  4.771641e+10
# 2    2  04  040000000000               Bremen  1.549716e+05  4.054809e+08
# 3    2  05  050000000000  Nordrhein-Westfalen  1.352108e+06  3.404727e+10
# 4    2  06  060000000000               Hessen  1.105093e+06  2.109232e+10
#
#                                             geometry
# 0  MULTIPOLYGON (((10.19114 53.72299, 10.18210 53...
# 1  MULTIPOLYGON (((8.68962 53.87999, 8.69297 53.8...
# 2  MULTIPOLYGON (((8.52976 53.21640, 8.55399 53.2...
# 3  POLYGON ((8.66673 52.52149, 8.70289 52.50053, ...
# 4  POLYGON ((9.50560 51.62777, 9.50842 51.62712, ...

# %%
# same as before but now we want to aggregate data for individual Bundesländer
res_intersect_bl = gpd.overlay(europe_data, bl, how='intersection')

# %%
res_intersect_bl.sample(5)
# Out:
#      country code  country           name of powerplant  capacity in MW  \
# 603           DEU  Germany   Sietzsch Solar Power Plant            10.0
# 822           DEU  Germany               KW Rheinfelden            46.7
# 138           DEU  Germany    Hurlach Solar Power Plant             4.3
# 1021          DEU  Germany            Leinefelde-Worbis             8.0
# 1273          DEU  Germany  W�rrstadt Solar Power Plant             5.6
#
#       latitude  longitude primary_fuel  start date    owner of plant  \
# 603    51.4896    12.1908        Solar          -1               NaN
# 822    47.5699     7.8101        Hydro        2010  Energiedienst AG
# 138    48.1074    10.8538        Solar          -1               NaN
# 1021   51.3844    10.3364        Solar          -1               NaN
# 1273   49.8289     8.1322        Solar          -1               NaN
#
#           geolocation_source  estimated_generation_gwh_2020  green continent  \
# 603           Industry About                          15.09   True    Europe
# 822   Open Power System Data                         133.24   True    Europe
# 138           Industry About                           5.91   True    Europe
# 1021              Wiki-Solar                          11.22   True    Europe
# 1273          Industry About                           8.45   True    Europe
#
#       USE  RS        RS_ALT               name    SHAPE_LENG    SHAPE_AREA  \
# 603     2  15  150000000000     Sachsen-Anhalt  9.490968e+05  2.049498e+10
# 822     2  08  080000000000  Baden-Württemberg  1.298892e+06  3.580140e+10
# 138     2  09  090000000000             Bayern  2.046039e+06  7.055007e+10
# 1021    2  16  160000000000          Thüringen  9.619427e+05  1.617853e+10
# 1273    2  07  070000000000    Rheinland-Pfalz  9.106504e+05  1.983491e+10
#
#                        geometry
# 603   POINT (12.19080 51.48960)
# 822    POINT (7.81010 47.56990)
# 138   POINT (10.85380 48.10740)
# 1021  POINT (10.33640 51.38440)
# 1273   POINT (8.13220 49.82890)

# %%
bl.set_index("name", inplace=True)
bl = insert_totals(bl, res_intersect_bl)
bl = insert_fuel_types(bl, res_intersect_bl)
bl
# Out:
#                         USE  RS        RS_ALT    SHAPE_LENG    SHAPE_AREA  \
# name
# Hamburg                   2  02  020000000000  1.752538e+05  7.605398e+08
# Niedersachsen             2  03  030000000000  2.016496e+06  4.771641e+10
# Bremen                    2  04  040000000000  1.549716e+05  4.054809e+08
# Nordrhein-Westfalen       2  05  050000000000  1.352108e+06  3.404727e+10
# Hessen                    2  06  060000000000  1.105093e+06  2.109232e+10
# Rheinland-Pfalz           2  07  070000000000  9.106504e+05  1.983491e+10
# Baden-Württemberg         2  08  080000000000  1.298892e+06  3.580140e+10
# Bayern                    2  09  090000000000  2.046039e+06  7.055007e+10
# Saarland                  2  10  100000000000  2.829108e+05  2.578542e+09
# Berlin                    2  11  110000000000  1.807512e+05  8.864801e+08
# Brandenburg               2  12  120000000000  1.295460e+06  2.965390e+10
# Mecklenburg-Vorpommern    2  13  130000000000  1.780981e+06  2.304468e+10
# Sachsen                   2  14  140000000000  9.792943e+05  1.840164e+10
# Sachsen-Anhalt            2  15  150000000000  9.490968e+05  2.049498e+10
# Thüringen                 2  16  160000000000  9.619427e+05  1.617853e+10
# Schleswig-Holstein        2  01  010000000000  1.217256e+06  1.585743e+10
#
#                                                                  geometry  \
# name
# Hamburg                 MULTIPOLYGON (((10.19114 53.72299, 10.18210 53...
# Niedersachsen           MULTIPOLYGON (((8.68962 53.87999, 8.69297 53.8...
# Bremen                  MULTIPOLYGON (((8.52976 53.21640, 8.55399 53.2...
# Nordrhein-Westfalen     POLYGON ((8.66673 52.52149, 8.70289 52.50053, ...
# Hessen                  POLYGON ((9.50560 51.62777, 9.50842 51.62712, ...
# Rheinland-Pfalz         POLYGON ((7.84657 50.87861, 7.85901 50.87733, ...
# Baden-Württemberg       MULTIPOLYGON (((9.64634 49.77782, 9.63806 49.7...
# Bayern                  POLYGON ((10.47207 47.56964, 10.47319 47.57081...
# Saarland                POLYGON ((7.06853 49.62349, 7.08023 49.61196, ...
# Berlin                  POLYGON ((13.61192 52.54332, 13.62461 52.53797...
# Brandenburg             POLYGON ((13.87357 53.47515, 13.91610 53.45652...
# Mecklenburg-Vorpommern  MULTIPOLYGON (((12.66717 54.44292, 12.67209 54...
# Sachsen                 POLYGON ((12.90084 51.64699, 12.91309 51.64488...
# Sachsen-Anhalt          POLYGON ((11.63624 53.00680, 11.64091 53.00601...
# Thüringen               POLYGON ((10.86498 51.62927, 10.89515 51.61114...
# Schleswig-Holstein      MULTIPOLYGON (((8.44703 55.05034, 8.46057 55.0...
#
#                         N_powerplants  N_green  green_ratio  N_fuel_Hydro  \
# name
# Hamburg                             7        1     0.142857           NaN
# Niedersachsen                      45       16     0.355556           2.0
# Bremen                              8        1     0.125000           1.0
# Nordrhein-Westfalen               131       24     0.183206           5.0
# Hessen                             42       19     0.452381           3.0
# Rheinland-Pfalz                    72       53     0.736111          10.0
# Baden-Württemberg                  95       59     0.621053          21.0
# Bayern                            305      261     0.855738          63.0
# Saarland                           24       14     0.583333           NaN
# Berlin                             11        1     0.090909           NaN
# Brandenburg                       156      137     0.878205           NaN
# Mecklenburg-Vorpommern             72       64     0.888889           NaN
# Sachsen                            81       67     0.827160           3.0
# Sachsen-Anhalt                    139      111     0.798561           1.0
# Thüringen                          53       43     0.811321           3.0
# Schleswig-Holstein                 52       41     0.788462           1.0
#
#                         ...  fuel_generation_ratio_Nuclear  \
# name                    ...
# Hamburg                 ...                       0.000000
# Niedersachsen           ...                       0.463524
# Bremen                  ...                       0.000000
# Nordrhein-Westfalen     ...                       0.000000
# Hessen                  ...                       0.000000
# Rheinland-Pfalz         ...                       0.000000
# Baden-Württemberg       ...                       0.334574
# Bayern                  ...                       0.508339
# Saarland                ...                       0.000000
# Berlin                  ...                       0.000000
# Brandenburg             ...                       0.000000
# Mecklenburg-Vorpommern  ...                       0.000000
# Sachsen                 ...                       0.000000
# Sachsen-Anhalt          ...                       0.000000
# Thüringen               ...                       0.000000
# Schleswig-Holstein      ...                       0.599500
#
#                         fuel_generation_total_Nuclear  N_fuel_Other  \
# name
# Hamburg                                          0.00           NaN
# Niedersachsen                                18588.72           1.0
# Bremen                                           0.00           NaN
# Nordrhein-Westfalen                              0.00           4.0
# Hessen                                           0.00           1.0
# Rheinland-Pfalz                                  0.00           NaN
# Baden-Württemberg                            19274.21           1.0
# Bayern                                       27264.80           NaN
# Saarland                                         0.00           1.0
# Berlin                                           0.00           NaN
# Brandenburg                                      0.00           2.0
# Mecklenburg-Vorpommern                           0.00           NaN
# Sachsen                                          0.00           NaN
# Sachsen-Anhalt                                   0.00           1.0
# Thüringen                                        0.00           NaN
# Schleswig-Holstein                            9946.24           NaN
#
#                         fuel_ratio_Other  fuel_generation_ratio_Other  \
# name
# Hamburg                         0.000000                     0.000000
# Niedersachsen                   0.022222                     0.023785
# Bremen                          0.000000                     0.000000
# Nordrhein-Westfalen             0.030534                     0.003987
# Hessen                          0.023810                     0.005029
# Rheinland-Pfalz                 0.000000                     0.000000
# Baden-Württemberg               0.010526                     0.003214
# Bayern                          0.000000                     0.000000
# Saarland                        0.041667                     0.024724
# Berlin                          0.000000                     0.000000
# Brandenburg                     0.012821                     0.013235
# Mecklenburg-Vorpommern          0.000000                     0.000000
# Sachsen                         0.000000                     0.000000
# Sachsen-Anhalt                  0.007194                     0.003725
# Thüringen                       0.000000                     0.000000
# Schleswig-Holstein              0.000000                     0.000000
#
#                         fuel_generation_total_Other  N_fuel_Wind  \
# name
# Hamburg                                        0.00          NaN
# Niedersachsen                                953.84          NaN
# Bremen                                         0.00          NaN
# Nordrhein-Westfalen                          559.39          NaN
# Hessen                                        65.13          NaN
# Rheinland-Pfalz                                0.00          NaN
# Baden-Württemberg                            185.14          NaN
# Bayern                                         0.00          NaN
# Saarland                                     281.03          NaN
# Berlin                                         0.00          NaN
# Brandenburg                                  411.62          4.0
# Mecklenburg-Vorpommern                         0.00          NaN
# Sachsen                                        0.00          NaN
# Sachsen-Anhalt                                46.28          6.0
# Thüringen                                      0.00          NaN
# Schleswig-Holstein                             0.00          2.0
#
#                         fuel_ratio_Wind  fuel_generation_ratio_Wind  \
# name
# Hamburg                        0.000000                    0.000000
# Niedersachsen                  0.000000                    0.000000
# Bremen                         0.000000                    0.000000
# Nordrhein-Westfalen            0.000000                    0.000000
# Hessen                         0.000000                    0.000000
# Rheinland-Pfalz                0.000000                    0.000000
# Baden-Württemberg              0.000000                    0.000000
# Bayern                         0.000000                    0.000000
# Saarland                       0.000000                    0.000000
# Berlin                         0.000000                    0.000000
# Brandenburg                    0.025641                    0.051980
# Mecklenburg-Vorpommern         0.000000                    0.000000
# Sachsen                        0.000000                    0.000000
# Sachsen-Anhalt                 0.043165                    0.081084
# Thüringen                      0.000000                    0.000000
# Schleswig-Holstein             0.038462                    0.056648
#
#                         fuel_generation_total_Wind
# name
# Hamburg                                       0.00
# Niedersachsen                                 0.00
# Bremen                                        0.00
# Nordrhein-Westfalen                           0.00
# Hessen                                        0.00
# Rheinland-Pfalz                               0.00
# Baden-Württemberg                             0.00
# Bayern                                        0.00
# Saarland                                      0.00
# Berlin                                        0.00
# Brandenburg                                1616.67
# Mecklenburg-Vorpommern                        0.00
# Sachsen                                       0.00
# Sachsen-Anhalt                             1007.44
# Thüringen                                     0.00
# Schleswig-Holstein                          939.84
#
# [16 rows x 49 columns]

# %% [markdown]
# ## German Landkreise
# Let's go even lower than Bundesländer

# %%
kreise = gpd.read_file('../data/vg2500_krs.zip').to_crs("EPSG:4326")
kreise.rename({"GEN": "name"}, axis=1, inplace=True)
kreise.sample(5)
# Out:
#      USE     RS        RS_ALT                 name     SHAPE_LENG  \
# 312    4  09774  097740000000             Günzburg  151126.841941
# 219    4  08426  084260000000             Biberach  214557.354650
# 65     4  05112  051120000000             Duisburg   76480.458049
# 161    4  07313  073130000000  Landau in der Pfalz   61094.274804
# 366    4  15082  150820000000    Anhalt-Bitterfeld  268526.034558
#
#        SHAPE_AREA                                           geometry
# 312  7.660444e+08  POLYGON ((10.42423 48.52114, 10.42234 48.51623...
# 219  1.414375e+09  POLYGON ((9.89724 48.29384, 9.89752 48.28848, ...
# 65   2.358640e+08  POLYGON ((6.78424 51.53198, 6.78317 51.53050, ...
# 161  9.034076e+07  MULTIPOLYGON (((8.12975 49.22772, 8.14057 49.2...
# 366  1.449396e+09  POLYGON ((12.31291 52.09361, 12.31393 52.09303...

# %% [markdown]
# repeat the stepts

# %%
res_intersect_kreise = gpd.overlay(europe_data, kreise, how='intersection')

# %%
kreise.set_index("name", inplace=True)
kreise = insert_totals(kreise, res_intersect_kreise)
kreise = insert_fuel_types(kreise, res_intersect_kreise)
kreise
# Out:
#                       USE     RS        RS_ALT     SHAPE_LENG    SHAPE_AREA  \
# name
# Flensburg               4  01001  010010000000   32467.034276  5.324899e+07
# Kiel                    4  01002  010020000000   73027.302434  1.218654e+08
# Lübeck                  4  01003  010030000000  104861.094220  2.211386e+08
# Neumünster              4  01004  010040000000   39858.818376  8.092363e+07
# Dithmarschen            4  01051  010510000000  202206.675707  1.450311e+09
# ...                   ...    ...           ...            ...           ...
# Saalfeld-Rudolstadt     4  16073  160730000000  209670.746788  1.023057e+09
# Saale-Holzland-Kreis    4  16074  160740000000  172686.880125  8.176883e+08
# Saale-Orla-Kreis        4  16075  160750000000  185679.957051  1.144877e+09
# Greiz                   4  16076  160760000000  222979.605428  8.509542e+08
# Altenburger Land        4  16077  160770000000  120639.356978  5.693369e+08
#
#                                                                geometry  \
# name
# Flensburg             POLYGON ((9.48982 54.82296, 9.50467 54.81004, ...
# Kiel                  POLYGON ((10.19057 54.38909, 10.18370 54.38910...
# Lübeck                POLYGON ((10.89297 53.95695, 10.90337 53.95705...
# Neumünster            POLYGON ((10.03454 54.12915, 10.02277 54.10938...
# Dithmarschen          MULTIPOLYGON (((9.05176 54.36640, 9.07193 54.3...
# ...                                                                 ...
# Saalfeld-Rudolstadt   POLYGON ((11.42397 50.80862, 11.42072 50.80306...
# Saale-Holzland-Kreis  POLYGON ((12.01807 50.96757, 12.02085 50.94806...
# Saale-Orla-Kreis      POLYGON ((11.94482 50.59236, 11.92423 50.58608...
# Greiz                 POLYGON ((12.22219 50.94284, 12.23787 50.92905...
# Altenburger Land      POLYGON ((12.61849 50.98093, 12.62331 50.96260...
#
#                       N_powerplants  N_green  green_ratio  N_fuel_Hydro  ...  \
# name                                                                     ...
# Flensburg                       1.0      0.0          0.0           NaN  ...
# Kiel                            2.0      0.0          0.0           NaN  ...
# Lübeck                          0.0      0.0          NaN           NaN  ...
# Neumünster                      0.0      0.0          NaN           NaN  ...
# Dithmarschen                    3.0      3.0          1.0           NaN  ...
# ...                             ...      ...          ...           ...  ...
# Saalfeld-Rudolstadt             2.0      1.0          0.5           1.0  ...
# Saale-Holzland-Kreis            0.0      0.0          NaN           NaN  ...
# Saale-Orla-Kreis                3.0      3.0          1.0           1.0  ...
# Greiz                           5.0      5.0          1.0           NaN  ...
# Altenburger Land                4.0      4.0          1.0           NaN  ...
#
#                       fuel_generation_ratio_Wind  fuel_generation_total_Wind  \
# name
# Flensburg                                    0.0                         0.0
# Kiel                                         0.0                         0.0
# Lübeck                                       NaN                         NaN
# Neumünster                                   NaN                         NaN
# Dithmarschen                                 0.0                         0.0
# ...                                          ...                         ...
# Saalfeld-Rudolstadt                          0.0                         0.0
# Saale-Holzland-Kreis                         NaN                         NaN
# Saale-Orla-Kreis                             0.0                         0.0
# Greiz                                        0.0                         0.0
# Altenburger Land                             0.0                         0.0
#
#                       N_fuel_Oil  fuel_ratio_Oil  fuel_generation_ratio_Oil  \
# name
# Flensburg                    NaN             0.0                        0.0
# Kiel                         NaN             0.0                        0.0
# Lübeck                       NaN             NaN                        NaN
# Neumünster                   NaN             NaN                        NaN
# Dithmarschen                 NaN             0.0                        0.0
# ...                          ...             ...                        ...
# Saalfeld-Rudolstadt          NaN             0.0                        0.0
# Saale-Holzland-Kreis         NaN             NaN                        NaN
# Saale-Orla-Kreis             NaN             0.0                        0.0
# Greiz                        NaN             0.0                        0.0
# Altenburger Land             NaN             0.0                        0.0
#
#                       fuel_generation_total_Oil  N_fuel_Nuclear  \
# name
# Flensburg                                   0.0             NaN
# Kiel                                        0.0             NaN
# Lübeck                                      NaN             NaN
# Neumünster                                  NaN             NaN
# Dithmarschen                                0.0             NaN
# ...                                         ...             ...
# Saalfeld-Rudolstadt                         0.0             NaN
# Saale-Holzland-Kreis                        NaN             NaN
# Saale-Orla-Kreis                            0.0             NaN
# Greiz                                       0.0             NaN
# Altenburger Land                            0.0             NaN
#
#                       fuel_ratio_Nuclear  fuel_generation_ratio_Nuclear  \
# name
# Flensburg                            0.0                            0.0
# Kiel                                 0.0                            0.0
# Lübeck                               NaN                            NaN
# Neumünster                           NaN                            NaN
# Dithmarschen                         0.0                            0.0
# ...                                  ...                            ...
# Saalfeld-Rudolstadt                  0.0                            0.0
# Saale-Holzland-Kreis                 NaN                            NaN
# Saale-Orla-Kreis                     0.0                            0.0
# Greiz                                0.0                            0.0
# Altenburger Land                     0.0                            0.0
#
#                       fuel_generation_total_Nuclear
# name
# Flensburg                                       0.0
# Kiel                                            0.0
# Lübeck                                          NaN
# Neumünster                                      NaN
# Dithmarschen                                    0.0
# ...                                             ...
# Saalfeld-Rudolstadt                             0.0
# Saale-Holzland-Kreis                            NaN
# Saale-Orla-Kreis                                0.0
# Greiz                                           0.0
# Altenburger Land                                0.0
#
# [402 rows x 49 columns]

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world_data = pd.read_pickle("../data/gdf_world.p").to_crs("EPSG:4326")
res_intersect_world = gpd.overlay(world_data, world, how='intersection')

# %%
world.set_index("name", inplace=True)
world = insert_totals(world, res_intersect_world)
world = insert_fuel_types(world, res_intersect_world)
world
# Out:
#                             pop_est      continent iso_a3  gdp_md_est  \
# name
# Fiji                         920938        Oceania    FJI      8374.0
# Tanzania                   53950935         Africa    TZA    150600.0
# W. Sahara                    603253         Africa    ESH       906.5
# Canada                     35623680  North America    CAN   1674000.0
# United States of America  326625791  North America    USA  18560000.0
# ...                             ...            ...    ...         ...
# Serbia                      7111024         Europe    SRB    101800.0
# Montenegro                   642550         Europe    MNE     10610.0
# Kosovo                      1895250         Europe    -99     18490.0
# Trinidad and Tobago         1218208  North America    TTO     43570.0
# S. Sudan                   13026129         Africa    SSD     20880.0
#
#                                                                    geometry  \
# name
# Fiji                      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# Tanzania                  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# W. Sahara                 POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# Canada                    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# United States of America  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ...                                                                     ...
# Serbia                    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# Montenegro                POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# Kosovo                    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# Trinidad and Tobago       POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# S. Sudan                  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                           N_powerplants  N_green  green_ratio  N_fuel_Hydro  \
# name
# Fiji                               10.0      8.0     0.800000           4.0
# Tanzania                           10.0      7.0     0.700000           6.0
# W. Sahara                           0.0      0.0          NaN           NaN
# Canada                           1116.0   1013.0     0.907706         550.0
# United States of America         9654.0   6028.0     0.624404        1421.0
# ...                                 ...      ...          ...           ...
# Serbia                              8.0      2.0     0.250000           2.0
# Montenegro                          3.0      2.0     0.666667           2.0
# Kosovo                              4.0      0.0     0.000000           NaN
# Trinidad and Tobago                 4.0      0.0     0.000000           NaN
# S. Sudan                            2.0      1.0     0.500000           NaN
#
#                           fuel_ratio_Hydro  ...  \
# name                                        ...
# Fiji                              0.400000  ...
# Tanzania                          0.600000  ...
# W. Sahara                              NaN  ...
# Canada                            0.492832  ...
# United States of America          0.147193  ...
# ...                                    ...  ...
# Serbia                            0.250000  ...
# Montenegro                        0.666667  ...
# Kosovo                            0.000000  ...
# Trinidad and Tobago               0.000000  ...
# S. Sudan                          0.000000  ...
#
#                           fuel_generation_ratio_Storage  \
# name
# Fiji                                                0.0
# Tanzania                                            0.0
# W. Sahara                                           NaN
# Canada                                              0.0
# United States of America                            0.0
# ...                                                 ...
# Serbia                                              0.0
# Montenegro                                          0.0
# Kosovo                                              0.0
# Trinidad and Tobago                                 0.0
# S. Sudan                                            0.0
#
#                           fuel_generation_total_Storage  N_fuel_Geothermal  \
# name
# Fiji                                                0.0                NaN
# Tanzania                                            0.0                NaN
# W. Sahara                                           NaN                NaN
# Canada                                              0.0                NaN
# United States of America                            0.0               65.0
# ...                                                 ...                ...
# Serbia                                              0.0                NaN
# Montenegro                                          0.0                NaN
# Kosovo                                              0.0                NaN
# Trinidad and Tobago                                 0.0                NaN
# S. Sudan                                            0.0                NaN
#
#                           fuel_ratio_Geothermal  \
# name
# Fiji                                   0.000000
# Tanzania                               0.000000
# W. Sahara                                   NaN
# Canada                                 0.000000
# United States of America               0.006733
# ...                                         ...
# Serbia                                 0.000000
# Montenegro                             0.000000
# Kosovo                                 0.000000
# Trinidad and Tobago                    0.000000
# S. Sudan                               0.000000
#
#                           fuel_generation_ratio_Geothermal  \
# name
# Fiji                                              0.000000
# Tanzania                                          0.000000
# W. Sahara                                              NaN
# Canada                                            0.000000
# United States of America                          0.004648
# ...                                                    ...
# Serbia                                            0.000000
# Montenegro                                        0.000000
# Kosovo                                            0.000000
# Trinidad and Tobago                               0.000000
# S. Sudan                                          0.000000
#
#                           fuel_generation_total_Geothermal  N_fuel_Petcoke  \
# name
# Fiji                                                  0.00             NaN
# Tanzania                                              0.00             NaN
# W. Sahara                                              NaN             NaN
# Canada                                                0.00             NaN
# United States of America                          21022.26            11.0
# ...                                                    ...             ...
# Serbia                                                0.00             NaN
# Montenegro                                            0.00             NaN
# Kosovo                                                0.00             NaN
# Trinidad and Tobago                                   0.00             NaN
# S. Sudan                                              0.00             NaN
#
#                           fuel_ratio_Petcoke  fuel_generation_ratio_Petcoke  \
# name
# Fiji                                0.000000                            0.0
# Tanzania                            0.000000                            0.0
# W. Sahara                                NaN                            NaN
# Canada                              0.000000                            0.0
# United States of America            0.001139                            0.0
# ...                                      ...                            ...
# Serbia                              0.000000                            0.0
# Montenegro                          0.000000                            0.0
# Kosovo                              0.000000                            0.0
# Trinidad and Tobago                 0.000000                            0.0
# S. Sudan                            0.000000                            0.0
#
#                           fuel_generation_total_Petcoke
# name
# Fiji                                                0.0
# Tanzania                                            0.0
# W. Sahara                                           NaN
# Canada                                              0.0
# United States of America                            0.0
# ...                                                 ...
# Serbia                                              0.0
# Montenegro                                          0.0
# Kosovo                                              0.0
# Trinidad and Tobago                                 0.0
# S. Sudan                                            0.0
#
# [177 rows x 68 columns]

# %%
world["name"] = world.index
bl["name"] = bl.index
kreise["name"] = kreise.index

# %%
europe.fillna(0).to_pickle("../data/europe_pp.p")
bl.fillna(0).to_pickle("../data/bl_pp.p")
kreise.fillna(0).to_pickle("../data/kreise_pp.p")
world.fillna(0).to_pickle("../data/world_pp.p")
res_intersect_kreise.to_pickle("../data/kreise_full.p")
res_intersect_world.to_pickle("../data/world_full.p")

# %%
res_intersect_kreise
# Out:
#      country code  country                name of powerplant  capacity in MW  \
# 0             AUT  Austria                   Braunau-Simbach           100.0
# 1             DEU  Germany                             Ering            36.5
# 2             DEU  Germany                          Malching             4.8
# 3             DEU  Germany         K�ching Solar Power Plant             5.6
# 4             AUT  Austria                       Jochenstein           132.0
# ...           ...      ...                               ...             ...
# 1288          DEU  Germany     W�lfersheim Solar Power Plant             5.3
# 1289          DEU  Germany  Heizkraftwerk Evonik Rheinfelden            16.0
# 1290          DEU  Germany                    KW Rheinfelden            46.7
# 1291          DEU  Germany                         KW Wyhlen            37.9
# 1292          DEU  Germany         Kraftwerk Grenzach-Wyhlen            40.0
#
#       latitude  longitude primary_fuel  start date  \
# 0      48.2440    13.0060        Hydro        1954
# 1      48.2935    13.1585        Hydro        1942
# 2      48.2965    13.1589        Solar          -1
# 3      48.5553    13.0228        Solar          -1
# 4      48.5184    13.7076        Hydro        1956
# ...        ...        ...          ...         ...
# 1288   50.3953     8.8275        Solar          -1
# 1289   47.5708     7.8072          Gas        1980
# 1290   47.5699     7.8101        Hydro        2010
# 1291   47.5524     7.6581        Hydro        1912
# 1292   47.5397     7.7069          Gas        2004
#
#                             owner of plant      geolocation_source  ...  \
# 0                                  Verbund                     WRI  ...
# 1                               Innwerk AG  Open Power System Data  ...
# 2                                      NaN              Wiki-Solar  ...
# 3                                      NaN          Industry About  ...
# 4                                  Verbund                   GEODB  ...
# ...                                    ...                     ...  ...
# 1288                                   NaN          Industry About  ...
# 1289                   Evonik Degussa GmbH  Open Power System Data  ...
# 1290                      Energiedienst AG  Open Power System Data  ...
# 1291                      Energiedienst AG  Open Power System Data  ...
# 1292  KGW - Kraftwerk Grenzach-Wyhlen GmbH  Open Power System Data  ...
#
#       is_Hydro  is_Solar is_Gas  is_Biomass is_Coal is_Other is_Waste  \
# 0         True     False  False       False   False    False    False
# 1         True     False  False       False   False    False    False
# 2        False      True  False       False   False    False    False
# 3        False      True  False       False   False    False    False
# 4         True     False  False       False   False    False    False
# ...        ...       ...    ...         ...     ...      ...      ...
# 1288     False      True  False       False   False    False    False
# 1289     False     False   True       False   False    False    False
# 1290      True     False  False       False   False    False    False
# 1291      True     False  False       False   False    False    False
# 1292     False     False   True       False   False    False    False
#
#       is_Wind  is_Oil is_Nuclear
# 0       False   False      False
# 1       False   False      False
# 2       False   False      False
# 3       False   False      False
# 4       False   False      False
# ...       ...     ...        ...
# 1288    False   False      False
# 1289    False   False      False
# 1290    False   False      False
# 1291    False   False      False
# 1292    False   False      False
#
# [1293 rows x 30 columns]
